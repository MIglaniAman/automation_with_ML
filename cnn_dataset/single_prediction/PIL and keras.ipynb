# %%
from PIL import Image

# %%
img=Image.open('cat_or_dog_1.jpg')

# %%
img.size
# Out:
# (960, 720)

# %%
img.show()

# %%
img.crop((180,70,680,680 ))
# Out:
# <PIL.Image.Image image mode=RGB size=500x610 at 0x25E5E707CC8>

# %%
Image.ROTATE_90
# Out:
# 2

# %%
  img.transpose(2)
# Out:
# <PIL.Image.Image image mode=RGB size=720x960 at 0x25E5E7F9148>

# %%
  img.size
# Out:
# (960, 720)

# %%
img.height
# Out:
# 720

# %%
img.width
# Out:
# 960

# %%
im=img.\

# %% [raw]
# f

# %%
from keras.preprocessing import image

# %%
img1 = image.load_img('cat_or_dog_1.jpg',target_size=(150,150))

# %%
type(img1)
# Out:
# PIL.Image.Image
